# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("finalprompts.csv")
df["prompt1"] = df["prompt1"].dropna()
df
# Out:
#    Unnamed: 0                                            prompt1  \
# 0           0  Generate code to add a learning rate scheduler...
# 1           1  Generate code to add a learning rate scheduler...
# 2           2  Generate code to add a learning rate scheduler...
# 3           3  Generate code to add a learning rate scheduler...
# 4           4  Adding a learning rate scheduler to the optimi...
# 5           5                                                NaN
# 6           6                                                NaN
# 7           7                                                NaN
# 8           8                                                NaN
#
#                                              prompt2  \
# 0  If available, write a function that ensures th...
# 1  If available, write a function that will ensur...
# 2  If available, write a function that will ensur...
# 3  If available, write a function that will ensur...
# ...

# %%
data =[]
for i in range(5):
    data.append(df.iloc[i])
df_data = pd.DataFrame(data[4])    
df_data.to_csv('data.txt', index=False)
