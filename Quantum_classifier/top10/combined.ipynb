# %%
laven5 = [0.48557692307692313,
 0.13861386138613863,
 0.6474358974358974,
 0.49388753056234724,
 0.11386138613861385,0.48557692307692313,
 0.13861386138613863,
 0.6474358974358974,
 0.49388753056234724,
 0.11386138613861385]

laven10 = [0.48557692307692313,
 0.13861386138613863,
 0.6474358974358974,
 0.49388753056234724,
 0.11386138613861385,
 0.08415841584158412,
 0.19306930693069302,
 0.1089108910891089,
 0.0643564356435643,
 0.10377358490566035 ,0.48557692307692313,
 0.13861386138613863,
 0.6474358974358974,
 0.49388753056234724,
 0.11386138613861385,
 0.08415841584158412,
 0.19306930693069302,
 0.1089108910891089,
 0.0643564356435643,
 0.10377358490566035]

import matplotlib.pyplot as plt

# %%
labels = ["Top 5 Generated Codes","Top 10 Generated Codes"]

# Plotting the box plot with updated labels
plt.figure(figsize=(5, 4))
plt.boxplot([laven5,laven10], patch_artist=True, notch=False, labels=labels)
plt.title(' Lavenshtein Distance for  Combined Codes')
plt.ylabel('Similarity Score')
plt.grid(True)
plt.show()
plt.savefig('lavenshtein_top5_whisker.png')

# %%
codeb5 =[ 0.5571526 , 0.46575067, 0.41632135, 0.43115206, 0.422485240,7169431807506464,
 0.24146578543082184,
 0.7461138698501997,
 0.7175750795700844,
 0.1930118677386887]

codeb10 = [0.37715260222507774,
 0.2857506663070021,
 0.23632135022677825,
 0.2511520587688557,
 0.24248523903289074,
 0.2668432526552825,
 0.23655678688441795,
 0.26651335788827624,
 0.2392447253570263,
 0.2206227489466151,0.5571526022250777,
 0.46575066630700207,
 0.41632135022677824,
 0.4311520587688557,
 0.4224852390328907,
 0.4468432526552825,
 0.41655678688441794,
 0.44651335788827623,
 0.4192447253570263,
 0.4006227489466151]

# %%
labels = ["Top 5 Generated Codes","Top 10 Generated Codes"]

# Plotting the box plot with updated labels
plt.figure(figsize=(5, 4))
plt.boxplot([codeb5,codeb10], patch_artist=True, notch=False, labels=labels)
plt.title(' Lavenshtein Distance for  Combined Codes')
plt.ylabel('Similarity Score')
plt.grid(True)
plt.show()
plt.savefig('lavenshtein_top5_whisker.png')
